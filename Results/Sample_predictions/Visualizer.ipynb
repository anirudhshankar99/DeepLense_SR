# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plot, axes = plt.subplots(2,3)
axes[0][0].imshow(np.load('Raw.npy')[0][0]*255,cmap='gray')
axes[0][1].imshow(np.load('Gold.npy')[0]*255,cmap='gray')
axes[0][2].imshow(np.load('ResnetSISR_sparse.npy')[0][0]*255,cmap='gray')
axes[1][0].imshow(np.load('ResnetSISR_sparse_deep.npy')[0][0]*255,cmap='gray')
axes[1][1].imshow(np.load('ResnetSISR_denoise.npy')[0][0]*255,cmap='gray')
axes[1][2].imshow(np.load('SRGan.npy')[0][0]*255,cmap='gray')
axes[0][0].set_title('LR Image')
axes[0][1].set_title('HR Image')
axes[0][2].set_title('ResnetSISR_sparse')
axes[1][0].set_title('ResnstSISR_sparse_deep')
axes[1][1].set_title('Resnet_denoise')
axes[1][2].set_title('SRGan')
# Out:
# Text(0.5, 1.0, 'SRGan')
